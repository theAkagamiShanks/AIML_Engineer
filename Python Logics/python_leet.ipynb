# %% [markdown]
# # This notebook is all about python leet
# #### https://media.licdn.com/dms/document/media/v2/D561FAQFWIoXCO2rp8g/feedshare-document-pdf-analyzed/B56ZVW_NFWHEAY-/0/1740921250540?e=1743033600&v=beta&t=qHw0WukT4T5gTyxIDm6UWtnLq0d-aTQTryFLQPBoexw

# %% [markdown]
# [\[## https://leetcode.com/problems/two-sum/\](https://leetcode.com/problems/two-sum/)](https://leetcode.com/problems/two-sum/)

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
num = [2,5,5,11]
target = 10

# num = [2,7,11,15]
# target = 9 

for i in range(len(num)):
    for j in range(i+1):
        if i == 0 and j==0:
            continue
        elif i == j:
            continue
        elif num[i]+num[j] == target:
            print(i,j)
            print("Got")
        else:
            pass
# Out:
# 1 1
# Got
# 2 1
# Got
# 2 2
# Got

# %%
import pandas as pd

# Create the dataframes
customers = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['Joe', 'Henry', 'Sam', 'Max']
})

orders = pd.DataFrame({
    'id': [1, 2],
    'customerId': [3, 1]
})
# Out:
# 0    True
# 1    True
# Name: customerId, dtype: bool

# %%
#  customers[customers['id'].isin(orders['customerId'])]

pd.DataFrame(customers[~customers['id'].isin(orders['customerId'])]["name"]).rename({"name":"Customers"},axis =1)
# [orders["customerId"].isin(customers["id"])]
# Out:
#   Customers
# 1     Henry
# 3       Max

# %% [markdown]
# ### Retrying once again

# %%
nums = [2,7,11,15]
target = 9

# %%
for i in range(len(num)):
    for j in range(i+1):
        if i == 0 and j==0:
            continue
        elif i == j:
            continue
        elif num[i]+num[j] == target:
            print(i,j)
            print("Got")
        else:
            pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for i in range(len(num)):
#       2     for j in range(i+1):
#       3         if i == 0 and j==0:
#
# NameError: name 'num' is not defined

# %% [markdown]
# # 26. Remove Duplicates from Sorted Array

# %%
def removeDuplicates(list_val) -> int:
    list_val.sort()
    list(set(list_val))

# %%
list_val = [1,1,2] 

for i in range(0,len(list_val)):
    for j in range(0,len(list_val)):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
import itertools

list_val = [1,2]  # Example list with two elements
indices = list(range(len(list_val)))  # Indices: [0, 1]

unique_permutations = list(itertools.permutations(indices))

print(unique_permutations)
# Out:
# [(0, 1), (1, 0)]

# %%
unique_permutations[0][0]
# Out:
# 0

# %%
list(range(len(list_val)))
# Out:
# [0, 1, 2]

# %%
list_val = [1,1,2] 
k = 0
for i in range(len(list_val)):
    print(i)
    #  i == 1 or (1 != 0 )   
    if i == 0 or list_val[i] != list_val[i - 1]:
        # LIST[0]            = 1
        list_val[k] = list_val[i]
        k += 1

# %%
list_val[-1]
# Out:
# 2

# %%
val
# Out:
# [1, 2]

# %% [markdown]
# https://leetcode.com/problems/plus-one/description/?envType=problem-list-v2&envId=array

# %% [markdown]
# 66. Plus One

# %%
digits = [1,2,3]

shk = [str(i) for i in digits] 
shk
# Out:
# ['1', '2', '3']

# %%
shk_2 = "".join(shk)
shk_3 = int(shk_2) + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 shk_2 = "".join(shk)
#       2 shk_3 = int(shk_2) + 1
# ----> 3 list(shk_3).split(" ")
#
# TypeError: 'int' object is not iterable

# %%
[int(i) for i in list(str(shk_3))]
# Out:
# [1, 2, 4]

# %% [markdown]
# ### https://leetcode.com/problems/valid-parentheses/

# %% [markdown]
# 20. Valid Parentheses

# %%
s = "()[]("

def 
val1 = list(s).count("(") == list(s).count(")")
val2 = list(s).count("[") == list(s).count("]")
val3 = list(s).count("{") == list(s).count("}")

if val1 == val2 == val3:
    return True
else:
    return False

# %%
def isValid(s):
    stack = []
    for char in s:
        print(f"Current char: {char}")
        if char == '(' or char == '[' or char == '{':
            stack.append(char)
            print(f"  Open bracket, stack now: {stack}")
        elif char == ')':
            if not stack or stack[-1] != '(':
                print("  Mismatch or empty stack for ')'")
                return False
            stack.pop()
            print(f"  Closed ')', stack now: {stack}")
        elif char == ']':
            if not stack or stack[-1] != '[':
                print("  Mismatch or empty stack for ']'")
                return False
            stack.pop()
            print(f"  Closed ']', stack now: {stack}")
        elif char == '}':
            if not stack or stack[-1] != '{':
                print("  Mismatch or empty stack for '}'")
                return False
            stack.pop()
            print(f"  Closed , stack now: {stack}")
    
    print(f"Final stack: {stack}")
    return len(stack) == 0

isValid("()[]")
# Out:
# Current char: (
#   Open bracket, stack now: ['(']
# Current char: )
#   Closed ')', stack now: []
# Current char: [
#   Open bracket, stack now: ['[']
# Current char: ]
#   Closed ']', stack now: []
# Final stack: []
# True

# %% [markdown]
# # 228. Summary Ranges
#
# #### https://leetcode.com/problems/summary-ranges/description/?envType=problem-list-v2&envId=array

# %%
nums = [0,1,2,4,5,7]
# nums =  [0,2,3,4,6,8,9]

# %%
nums = [0,1,2,4,5,7]
values = []
start = nums[0]

for i in range(1, len(nums)):
    if nums[i] != nums[i-1] + 1:
        if start == nums[i-1]:
            values.append(str(start))
        else:
            values.append(f"{start}->{nums[i-1]}")
        start = nums[i]

# Add the last range
if start == nums[-1]:
    values.append(str(start))
else:
    values.append(f"{start}->{nums[-1]}")

print(values)
# Out:
# ['0', '2->4', '6', '8->9']

# %%
values
# Out:
# []

# %% [markdown]
# ### 3467. Transform Array by Parity
#
# You are given an integer array nums. Transform nums by performing the following operations in the exact order specified:
#
# Replace each even number with 0.
# Replace each odd numbers with 1.
# Sort the modified array in non-decreasing order.
# Return the resulting array after performing these operations.

# %%
nums = [4,3,2,1]

# %%
vals = []
for i in nums:
    if i % 2 == 0:
        vals.append(0)
    else:
        vals.append(1)

for i in range(len(vals)):
    for j in range(len(vals)-1):
        print(i,j+1)
            # 1 < 0
        if vals[j] > vals[j+1]:
            vals[j] , vals[j+1] =  vals[j+1] , vals[j]
# Out:
# 0 1
# 0 2
# 0 3
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %% [markdown]
# ## 387. First Unique Character in a String

# %%
s = "leetcode"

# %%
from collections import Counter
def word_to_get(s):
    repeat = []
    unique =[]
    dict_word = dict(Counter(s))
    print(dict_word)
    for i,j in enumerate(list(s)):
        # print(i,j)
        if dict_word.get(j) == 1:
            # print(i)
            unique.append(i)
        else:
            repeat.append(i)
    print(unique)
    if len(unique)>0:
        return unique[0]
    else:
        return -1

# %%
s = "aabb"
ans = word_to_get(s)
print(ans)
# Out:
# {'a': 2, 'b': 2}
# []
# -1

# %% [markdown]
# ## 1684. Count the Number of Consistent Strings

# %%
allowed = "ab"
words = ["ad","bd","aaab","baa","badab"]

# %%
print(f"Allowed word : {allowed}")
allowed_count = []
not_allowed_count = []
for i in words:
    all_present = True
    print(f"Checking word: {i}")
    for char in i:

        if char not in allowed:
            all_present = False
            break
        
    if all_present:
        print("Allowed")
        allowed_count.append("Allowed")
    else:
        print("Not Allowed")
        not_allowed_count.append("Not Allowed")
# Out:
# Allowed word : ab
# Checking word: ad
# Not Allowed
# Checking word: bd
# Not Allowed
# Checking word: aaab
# Allowed
# Checking word: baa
# Allowed
# Checking word: badab
# Not Allowed
